# %%
import matplotlib.pyplot as plt

# %%
months=['Jan','Feb','Mar','Apr']
sales=[2000,3000,2500,3600]

# %% [markdown]
# # plt.plot(x,y,color='color name',linestyle='line_style',linewidth=value,marker='marker symbol',label='label name')

# %%
plt.plot(months,sales,color='lightgreen',linestyle='-.',linewidth=2,marker='o',label='Monthly Sales Data')
plt.xlabel('Months')
plt.ylabel('Sales')
plt.title('Monthly Sales Report')
plt.xlim(0,4)
plt.ylim(2000,4000)
plt.grid(True)
plt.legend(loc='upper left',fontsize=12)
plt.show()

# %%
import numpy as np

# %%
x=np.linspace(0,2,100)# to create 100 line with even space of 0 to 2
plt.plot(x,x,label='Linear')
plt.plot(x,x**2,label='Quadratic')
plt.plot(x,x**3,label='Cubic')
plt.xlabel('X Lines')
plt.ylabel('Y Lines')
plt.title('Simple Lines Plot')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# # Bar Plot Example
#  ## plt.bar(x,y,color='',edgecolor='')

# %%
categories=['Electronics','Mobiles','Books','Groceries','Home Decoration']
sales=[50000,60000,30000,90000,40000]
bar_colors=['red','blue','green','purple','orange']
plt.figure(figsize=(8,5))
plt.bar(categories,sales,color=bar_colors,edgecolor='black')
plt.xlabel('Categories')
plt.ylabel('Sales Amount (MYR)')
plt.title('Categories wise Sales Report')
plt.grid(axis='y',linestyle='--',color='green',alpha=0.5)
plt.tight_layout()
plt.show()

# %%
categories=['Electronics','Mobiles','Books','Groceries','Home Decoration']
sales=[50000,60000,30000,90000,40000]
plt.figure(figsize=(8,5))
plt.bar(categories,sales,color='lightblue',edgecolor='black',label='Sales Info')
plt.xlabel('Categories')
plt.ylabel('Sales Amount (MYR)')
plt.title('Categories wise Sales Report')
plt.grid(axis='y',linestyle='--',color='green',alpha=0.5)
plt.xticks(rotation=30, fontsize=12, color='magenta')
plt.yticks([20000,40000,60000,80000,100000],['20k','40k','60k','80k','1M'],fontsize=12,color='green')
plt.legend(title='Legend',fontsize=8)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Scatter Plot
#  ## plt.scatter(x,y,s='',c='color name',marker='markername',alpha=transparency,edgecolor='colorname',label='label of legend'

# %%
height_cm=[150,155,160,165,170,175,180,185]
weight_kg=[50,53,56,62,66,68,72,85]
plt.figure(figsize=(8,5))
plt.scatter(height_cm,weight_kg,s=100,c='green',marker='*',alpha=0.9,edgecolor='black',label='weight height comparison')
plt.title('Scatter Plot Height Vs Weight')
plt.xlabel('Height(cm)')
plt.ylabel('Weight(kg)')
plt.xticks(rotation=45, fontsize=12, color='green')
plt.yticks([50,55,60,65,70,75,80,85],['50KG','55KG','60KG','65KG','70KG','75KG','80KG','85KG'],fontsize=12,color='green')
plt.grid(color='lightblue',alpha=0.5,linestyle='--',linewidth=0.5)
plt.legend()
plt.show()
